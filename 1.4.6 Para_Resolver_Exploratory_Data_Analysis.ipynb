# %% [markdown]
# # Practical Statistics for Data Scientists (Python)
# # Exploratory Data Analysis
# > (c) 2019 Peter C. Bruce, Andrew Bruce, Peter Gedeck

# %% [markdown]
# Importe los paquetes de Python necesarios.

# %%
# %matplotlib inline

# !pip install wquantiles #paquete "wquantiles" utilizando el comando de instalación de paquetes de Python. "wquantiles" proporciona una implementación de cuantiles ponderados, que podría ser útil para ciertos cálculos estadísticos.

from pathlib import Path #importa la clase Path del módulo pathlib, que se utiliza para manejar rutas de archivos y directorios de manera más sencilla y consistente.

import pandas as pd #es una biblioteca muy utilizada para la manipulación y análisis de datos estructurados en forma de DataFrames.
import numpy as np #es una biblioteca fundamental para la computación numérica en Python.
from scipy.stats import trim_mean #trim_mean se utiliza para calcular la media recortada, que es una medida robusta de tendencia central.
from statsmodels import robust # proporciona funciones para cálculos robustos en estadísticas.
import wquantiles #  biblioteca para cuantiles ponderados.

import seaborn as sns#biblioteca de visualización de datos basada en Matplotlib que facilita la creación de gráficos atractivos.
import matplotlib.pylab as plt #se utiliza para crear gráficos utilizando la interfaz de estilo MATLAB.

# %%
# # Inicia un bloque de código que intentará ejecutar algunas instrucciones. Si ocurre una excepción en este bloque, se pasará al bloque except.
  #  import common#Intenta importar el módulo llamado common. Si esta importación tiene éxito, significa que hay un módulo llamado common disponible.
   # DATA = common.dataDirectory() #Si la importación del módulo common falla (es decir, se produce una excepción ImportError), se pasa al bloque except.
    #except ImportError:
    #DATA = Path().resolve() / 'data' # En este bloque except, se utiliza la clase Path para crear una ruta al directorio de datos. Path().resolve() crea una ruta absoluta al directorio actual y luego se agrega / 'data' para construir la ruta completa al directorio de datos.

# %%
try:
    import common
    DATA = common.dataDirectory()
except ImportError:
    DATA = Path().resolve() / 'data'
  #En resumen, el código intenta obtener la ubicación del directorio de datos de dos formas diferentes. Si el módulo common está disponible, utiliza su función para obtener la ubicación. Si no, construye la ubicación utilizando la clase Path. Esto permite que el código sea más flexible y pueda funcionar en diferentes situaciones,
  #independientemente de si el módulo common está presente o no.

# %% [markdown]
# Definir rutas a conjuntos de datos. Si no mantiene sus datos en el mismo directorio que el código, adapte los nombres de las rutas.

# %%
AIRLINE_STATS_CSV = 'airline_stats.csv'
KC_TAX_CSV = 'kc_tax.csv'
LC_LOANS_CSV = 'lc_loans.csv'
AIRPORT_DELAYS_CSV ='dfw_airline.csv'
SP500_DATA_CSV = 'sp500_data.csv.gz'
SP500_SECTORS_CSV = 'sp500_sectors.csv'
STATE_CSV = '/content/state.csv'

# %%
#print(DATA /'state.csv')

# %% [markdown]
# # Estimaciones de ubicación
# ## Ejemplo: Estimaciones de ubicación de las tasas de población y homicidios

# %%
# Table 1-2

state = pd.read_csv(STATE_CSV)
print(state.head(8))
# Out:
#          State  Population  Murder.Rate Abbreviation
# 0      Alabama     4779736          5.7           AL
# 1       Alaska      710231          5.6           AK
# 2      Arizona     6392017          4.7           AZ
# 3     Arkansas     2915918          5.6           AR
# 4   California    37253956          4.4           CA
# 5     Colorado     5029196          2.8           CO
# 6  Connecticut     3574097          2.4           CT
# 7     Delaware      897934          5.8           DE

# %% [markdown]
# Calcule la media, la media recortada y la mediana de la población. Para `media` y `mediana` podemos usar los métodos _pandas_ del data frame. La media recortada requiere la función `trim_mean` en _scipy.stats_.

# %%
# escriba su código

from scipy.stats import trim_mean

# Cargar el archivo CSV en un DataFrame (reemplaza 'state.csv' con la ruta correcta)
state = pd.read_csv('/content/state.csv')

# Calcular la media
media = state['Population'].mean()

# Calcular la media recortada (por ejemplo, un recorte del 10%)calcular el valor promedio de un conjunto de datos después de eliminar un cierto porcentaje de los valores extremos en ambos extremos de la distribución.
media_recortada = trim_mean(state['Population'], proportiontocut=0.1)

# Calcular la mediana
mediana = state['Population'].median()

# Imprimir los resultados
print("Population")
print("Media:", media)
print("Media recortada:", media_recortada)
print("Mediana:", mediana)
# Out:
# Population
# Media: 6162876.3
# Media recortada: 4783697.125
# Mediana: 4436369.5

# %% [markdown]
# media ponderada  se tiene en cuenta la importancia relativa de cada componente. no se tratan todos los valores por igual al calcular la media, se les asignan pesos que indican su importancia relativa en la media final.

# %% [markdown]
# La media ponderada está disponible con numpy. Para la mediana ponderada, podemos usar el paquete especializado `wquantiles` (https://pypi.org/project/wquantiles/).

# %%
# escriba su código

# %% [markdown]
# # Estimates of Variability

# %%
# Table 1-2
print(state.head(8))
# Out:
#          State  Population  Murder.Rate Abbreviation
# 0      Alabama     4779736          5.7           AL
# 1       Alaska      710231          5.6           AK
# 2      Arizona     6392017          4.7           AZ
# 3     Arkansas     2915918          5.6           AR
# 4   California    37253956          4.4           CA
# 5     Colorado     5029196          2.8           CO
# 6  Connecticut     3574097          2.4           CT
# 7     Delaware      897934          5.8           DE

# %% [markdown]
# Standard deviation

# %%
# calcule
state.std()
# Out:
# <ipython-input-34-41611d17a707>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   state.std()
# Population     6.848235e+06
# Murder.Rate    1.915736e+00
# dtype: float64

# %% [markdown]
# El rango intercuartil se calcula como la diferencia del cuantil 75% y 25%.

# %%
#calcule#Calcula el percentil 25% (Q1)
q1 = np.percentile(state, 25)

# Calcula el percentil 75% (Q3)
q3 = np.percentile(state, 75)

# Calcula el rango intercuartil (IQR)
iqr = q3 - q1

print("Percentil 25% (Q1):", q1)
print("Percentil 75% (Q3):", q3)
print("Rango intercuartil (IQR):", iqr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-b7dec90a0aac> in <cell line: 3>()
#       1 #calcule#Calcula el percentil 25% (Q1)
#       2 # Convierte los valores en 'state' a números enteros
# ----> 3 state = [int(x) for x in state]
#       4
#       5 q1 = np.percentile(state, 25)
#
# <ipython-input-43-b7dec90a0aac> in <listcomp>(.0)
#       1 #calcule#Calcula el percentil 25% (Q1)
#       2 # Convierte los valores en 'state' a números enteros
# ----> 3 state = [int(x) for x in state]
#       4
#       5 q1 = np.percentile(state, 25)
#
# ValueError: invalid literal for int() with base 10: 'State'

# %%
#calcule
df.quantile([.25,.5,.75])

# %% [markdown]
# La desviación absoluta de la mediana de la mediana se puede calcular con un método en _statsmodels_

# %%
# su código

# %% [markdown]
# ## Percentiles and Boxplots
# _Pandas_ tiene el método `quantile` para data frames

# %%
print(state['Murder.Rate'].quantile([0.05, 0.25, 0.5, 0.75, 0.95]))
# Out:
# 0.05    1.600
# 0.25    2.425
# 0.50    4.000
# 0.75    5.550
# 0.95    6.510
# Name: Murder.Rate, dtype: float64

# %%
# Table 1.4
percentages = [0.05, 0.25, 0.5, 0.75, 0.95]
df = pd.DataFrame(state['Murder.Rate'].quantile(percentages))
df.index = [f'{p * 100}%' for p in percentages]
print(df.transpose())
# Out:
#              5.0%  25.0%  50.0%  75.0%  95.0%
# Murder.Rate   1.6  2.425    4.0   5.55   6.51

# %% [markdown]
# _Pandas_ proporciona una serie de tramas exploratorias básicas; uno de ellos son diagramas de caja

# %%
# genere un gráfico de caja

# %% [markdown]
# ## Frequency Table and Histograms
# El método `cut` para datos _pandas_ divide el conjunto de datos en contenedores. Hay una serie de argumentos para el método. El siguiente código crea contenedores de igual tamaño. El método `value_counts` devuelve una tabla de frecuencia.

# %%
binnedPopulation = pd.cut(state['Population'], 10)
print(binnedPopulation.value_counts())
# Out:
# (526935.67, 4232659.0]      24
# (4232659.0, 7901692.0]      14
# (7901692.0, 11570725.0]      6
# (11570725.0, 15239758.0]     2
# (15239758.0, 18908791.0]     1
# (18908791.0, 22577824.0]     1
# (22577824.0, 26246857.0]     1
# (33584923.0, 37253956.0]     1
# (26246857.0, 29915890.0]     0
# (29915890.0, 33584923.0]     0
# Name: Population, dtype: int64

# %%
# Table 1.5
binnedPopulation.name = 'binnedPopulation'
df = pd.concat([state, binnedPopulation], axis=1)
df = df.sort_values(by='Population')

groups = []
for group, subset in df.groupby(by='binnedPopulation'):
    groups.append({
        'BinRange': group,
        'Count': len(subset),
        'States': ','.join(subset.Abbreviation)
    })
print(pd.DataFrame(groups))
# Out:
#                    BinRange  Count  \
# 0    (526935.67, 4232659.0]     24
# 1    (4232659.0, 7901692.0]     14
# 2   (7901692.0, 11570725.0]      6
# 3  (11570725.0, 15239758.0]      2
# 4  (15239758.0, 18908791.0]      1
# 5  (18908791.0, 22577824.0]      1
# 6  (22577824.0, 26246857.0]      1
# 7  (26246857.0, 29915890.0]      0
# 8  (29915890.0, 33584923.0]      0
# 9  (33584923.0, 37253956.0]      1
#
#                                               States
# 0  WY,VT,ND,AK,SD,DE,MT,RI,NH,ME,HI,ID,NE,WV,NM,N...
# 1          KY,LA,SC,AL,CO,MN,WI,MD,MO,TN,AZ,IN,MA,WA
# 2                                  VA,NJ,NC,GA,MI,OH
# 3                                              PA,IL
# 4                                                 FL
# 5                                                 NY
# 6                                                 TX
# 7
# 8
# 9                                                 CA

# %% [markdown]
# _Pandas_ también admite histogramas para el análisis exploratorio de datos.

# %%
#Genere un Histograma

# %% [markdown]
# ## Density Estimates
# La densidad es una alternativa a los histogramas que puede proporcionar más información sobre la distribución de los puntos de datos. Utilice el argumento `bw_method` para controlar la suavidad de la curva de densidad.

# %%
# Genere un Histograma y la línea de tendencia

# %% [markdown]
# # Exploring Binary and Categorical Data

# %%
# Table 1-6
dfw = pd.read_csv(AIRPORT_DELAYS_CSV)
print(100 * dfw / dfw.values.sum())
# Out:
#      Carrier        ATC   Weather  Security    Inbound
# 0  23.022989  30.400781  4.025214  0.122937  42.428079

# %% [markdown]
# _Pandas_ también admite gráficos de barras para mostrar una sola variable categórica.

# %%
#Genere un gráfico de barras

# %% [markdown]
# # Correlation
# Primera lectura de los datasets

# %%
sp500_sym = pd.read_csv(SP500_SECTORS_CSV)
sp500_px = pd.read_csv(SP500_DATA_CSV, index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-f6c5a1bbb411> in <cell line: 1>()
# ----> 1 sp500_sym = pd.read_csv(SP500_SECTORS_CSV)
#       2 sp500_px = pd.read_csv(SP500_DATA_CSV, index_col=0)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
# Table 1-7
# Determine telecommunications symbols
telecomSymbols = sp500_sym[sp500_sym['sector'] == 'telecommunications_services']['symbol']

# Filter data for dates July 2012 through June 2015
telecom = sp500_px.loc[sp500_px.index >= '2012-07-01', telecomSymbols]
telecom.corr()
print(telecom)
# Out:
#                    T       CTL       FTR        VZ      LVLT
# 2012-07-02  0.422496  0.140847  0.070879  0.554180 -0.519998
# 2012-07-03 -0.177448  0.066280  0.070879 -0.025976 -0.049999
# 2012-07-05 -0.160548 -0.132563  0.055128 -0.051956 -0.180000
# 2012-07-06  0.342205  0.132563  0.007875  0.140106 -0.359999
# 2012-07-09  0.136883  0.124279 -0.023626  0.253943  0.180000
# ...              ...       ...       ...       ...       ...
# 2015-06-25  0.049342 -1.600000 -0.040000 -0.187790 -0.330002
# 2015-06-26 -0.256586  0.039999 -0.070000  0.029650 -0.739998
# 2015-06-29 -0.098685 -0.559999 -0.060000 -0.504063 -1.360000
# 2015-06-30 -0.503298 -0.420000 -0.070000 -0.523829  0.199997
# 2015-07-01 -0.019737  0.080000 -0.050000  0.355811  0.139999
#
# [754 rows x 5 columns]

# %% [markdown]
# A continuación, nos centramos en los fondos negociados en las principales bolsas (sector == 'etf').

# %%
etfs = sp500_px.loc[sp500_px.index > '2012-07-01',
                    sp500_sym[sp500_sym['sector'] == 'etf']['symbol']]
print(etfs.head())
# Out:
#                  XLI       QQQ       SPY       DIA       GLD    VXX       USO  \
# 2012-07-02 -0.376098  0.096313  0.028223 -0.242796  0.419998 -10.40  0.000000
# 2012-07-03  0.376099  0.481576  0.874936  0.728405  0.490006  -3.52  0.250000
# 2012-07-05  0.150440  0.096313 -0.103487  0.149420  0.239991   6.56 -0.070000
# 2012-07-06 -0.141040 -0.491201  0.018819 -0.205449 -0.519989  -8.80 -0.180000
# 2012-07-09  0.244465 -0.048160 -0.056445 -0.168094  0.429992  -0.48  0.459999
#
#                  IWM       XLE       XLY       XLU       XLB       XTL  \
# 2012-07-02  0.534641  0.028186  0.095759  0.098311 -0.093713  0.019076
# 2012-07-03  0.926067  0.995942  0.000000 -0.044686  0.337373  0.000000
# 2012-07-05 -0.171848 -0.460387  0.306431 -0.151938  0.103086  0.019072
# 2012-07-06 -0.229128  0.206706  0.153214  0.080437  0.018744 -0.429213
# 2012-07-09 -0.190939 -0.234892 -0.201098 -0.035751 -0.168687  0.000000
#
#                  XLV       XLP       XLF       XLK
# ...

# %% [markdown]
# Debido a la gran cantidad de columnas en esta tabla, mirar la matriz de correlación es engorroso y es más conveniente trazar la correlación como un mapa de calor. El paquete _seaborn_ proporciona una implementación conveniente para los mapas de calor.

# %%
#Genere un mapa de calor

# %% [markdown]
# ## Scatterplots
# Los diagramas de dispersión simples son compatibles con _pandas_. Especificar el marcador como `$\u25EF$` usa un círculo abierto para cada punto.

# %%
# Genere un gráfico de Correlación entre ATT vs VERIZON

# %% [markdown]
# ## Two Categorical Variables
# Carge el dataset `lc_loans`

# %%
lc_loans = pd.read_csv(LC_LOANS_CSV)

# %%
# Table 1-8(1)
crosstab = lc_loans.pivot_table(index='grade', columns='status',
                                aggfunc=lambda x: len(x), margins=True)
print(crosstab)
# Out:
# status  Charged Off  Current  Fully Paid  Late     All
# grade
# A              1562    50051       20408   469   72490
# B              5302    93852       31160  2056  132370
# C              6023    88928       23147  2777  120875
# D              5007    53281       13681  2308   74277
# E              2842    24639        5949  1374   34804
# F              1526     8444        2328   606   12904
# G               409     1990         643   199    3241
# All           22671   321185       97316  9789  450961

# %%
# Table 1-8(2)
df = crosstab.copy().loc['A':'G',:]
df.loc[:,'Charged Off':'Late'] = df.loc[:,'Charged Off':'Late'].div(df['All'], axis=0)
df['All'] = df['All'] / sum(df['All'])
perc_crosstab = df
print(perc_crosstab)
# Out:
# status  Charged Off   Current  Fully Paid      Late       All
# grade
# A          0.021548  0.690454    0.281528  0.006470  0.160746
# B          0.040054  0.709013    0.235401  0.015532  0.293529
# C          0.049828  0.735702    0.191495  0.022974  0.268039
# D          0.067410  0.717328    0.184189  0.031073  0.164708
# E          0.081657  0.707936    0.170929  0.039478  0.077177
# F          0.118258  0.654371    0.180409  0.046962  0.028614
# G          0.126196  0.614008    0.198396  0.061401  0.007187

# %% [markdown]
# ## Categorical and Numeric Data
# Los diagramas de caja _Pandas_ de una columna se pueden agrupar por una columna diferente.

# %%
# Genere un diagrama de caja de pct_carrier_delay para todas las líneas aéreas

# %% [markdown]
# _Pandas_ también admite una variación de diagramas de caja llamada _violinplot_.

# %%
# Genere un diagrama de violín para los mismos datos
