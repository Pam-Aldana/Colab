# %% [markdown]
# # Redes Convolucionales
#
# Keras nos permite crear redes convolucionales para procesar imágenes usando la capa `keras.layers.Conv2D`. Los parámetros para estas capas serán los que estudiamos para capas convlucionales (cantidad de kernels, tamaño de cada kernel, stride, tipo de padding, etc.). Podemos mezclarla también con capas de pooling como `keras.layers.MaxPool2D` y  las capas densas que ya hemos visto.

# %% [markdown]
# Comenzamos importando las librerías iniciales y mostrando algunos ejemplos.

# %%
from tensorflow import keras
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

# %%
(imgs_train, labs_train), (imgs_test, labs_test) = keras.datasets.cifar10.load_data()
print(imgs_train.shape)
print(imgs_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
nombres = ['avión', 'auto', 'pájaro', 'gato', 'venado', 'perro', 'rana', 'caballo', 'barco', 'camión']

# %%
# Mostramos una grilla de ejemplos (al azar) del conjunto de test

h = 6 # alto de la grilla
w = 6 # ancho de la grilla
fig, axs = plt.subplots(h, w, figsize=(1.6*h,1.6*w))
for i in range(h):
  for j in range(w):
    ex = np.random.randint(len(imgs_test))
    axs[i,j].set_title(nombres[labs_test[ex][0]])
    axs[i,j].grid(False)
    axs[i,j].set_xticklabels([])
    axs[i,j].set_yticklabels([])
    axs[i,j].imshow(imgs_test[ex])

# %%
# Normalizamos los datos de imagenes pero no cambiamos la forma

X_train = imgs_train
X_train = X_train / 255

X_test = imgs_test
X_test = X_test / 255

print(X_train.shape, X_test.shape)

# Las etiquetas si debemos llevarlas a un vector one-hot

Y_train = keras.utils.to_categorical(labs_train, 10)
Y_test = keras.utils.to_categorical(labs_test, 10)

print(Y_train.shape, Y_test.shape)
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# (50000, 10) (10000, 10)

# %% [markdown]
# ## Importando capas
#
# Ahora comenzaremos a usar más tipos de capas distintas por lo que será conveniente importarlas para no tener que anteponer `keras.layers` cada vez que las usemos. Las capas que usaremos inicialmente serán `Dense`, `Conv2D`, `MaxPool2D` y `Flatten` (esta última se usa para cambiar la forma de los datos de manera de que puedan ser entregados a una red feed-forward).

# %%
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten

# %% [markdown]
# ##  Nuestra primera red convolucional
#
# El siguiente código  crea una red con la siguiente arquitectura
#
# **Convolucional 64 (3x3) --> Max Pooling (2x2) --> Densa 128 (relu) --> Densa 10 **
#
# Las capas se agregan igual que para redes feed-forward. Hay un par de cosas que sería bueno que notes:
#
# - Nota el parámetro `input_shape` de la primera capa. Es similar al `input_dim` de la primera capa densa, pero ahora la forma de la entrada es un tensor que representa a la imagen con su forma habitual `(32,32,3)` es decir, imágenes de 32x32 pixeles y 3 canales de color.
# - Nota que hemos usado la capa `Flatten` entre la capa de max pooling y la capa densa. Esto es para cambiar la forma de los tensores que fluyen por la red.
#
# Mira el resumen de la arquitectura de la red y asegúrate que entiendes la forma de la salida de cada capa (es importante entenderlo pues te servirá después para encontrar posibles errores en el código y en el entrenamiento).

# %%
# Creamos una red neuronal convolucional simple

red_conv = keras.Sequential()
#Según la PPT
#Los hiperParámetros en la capa Conv2d quedan así:
#K = Numero de Kernels en la capa
#F = Extensión espacial del kernel (tamaño)
#S = el Stride = De cuantos pixeles avanzo en cada iteración de la aplicación de la convolución
#P = el Padding = La cantidad de pixeles a agregar en los bordes llenos con ceros. Para un Kernel de 3x3, la idea es un padding de 2x2, esto agrega 1 pixel arriba, 1 abajo, 1 a la izq y uno a la der
#Conv2D(K, F, strides=S, input_shape=(32,32,3), activation='relu')
#MaxPoll2D(Tamaño, S)
#Con esto se puede calcular el tamaño del mapa de activación resultante de la capa, así:
#Considerando que la entrada tiene tamaño W (si la imagen es de 5x5, entonces W = 5)
#Para el ejemplo de abajo, sería: W=32, K=64, F=3, S=1, P=1       -> Padding 1 porque al ser 2x2 agrega 1 pixel a cada lado, y la fórmula siguiente considera cada parámetro como 1 lado
#La fórmula es: ((W-F+2P)/S)+1
#Entonces: ((32-3+2*1)/1)+1 = 32    -> Manteniendo la relación de aspecto de la imagen de entrada con la de salida

#La fórmula para calcular los parámetros de la capa convolucional es:
# K x (tamaño del kernel) + K
# Si el kernel es de 3x3 y las imágenes tiene 3 canales de entrada (por ser RGB), entonces el kernel es 3x3x3
# La fórmula sería: 64 * (3 * 3 * 3) + 64 = 1792

red_conv.add(Conv2D(64, (3,3), strides=(1, 1), input_shape=(32,32,3), activation='relu')) #-> Primero se aplican las convoluciones, luego la función de activación
red_conv.add(MaxPool2D((2,2)))
red_conv.add(Flatten())
red_conv.add(Dense(128, activation='relu'))
red_conv.add(Dense(10, activation='softmax'))

red_conv.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 64)        1792
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 64)        0
#  D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 128)               1843328
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1846410 (7.04 MB)
# Trainable params: 1846410 (7.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Entrenando
#
# Ahora entrenamos por 25 épocas.

# %%
np.random.seed(30)
tf.random.set_seed(30)

red_conv.compile(
    loss='categorical_crossentropy',
    optimizer='sgd',  #-> adam es mejor función de optimizador que sgd
    metrics=['accuracy']
)

hist = red_conv.fit(
    X_train,Y_train,
    batch_size=64,
    epochs=25,
    validation_data=(X_test,Y_test)
)
# Out:
# Epoch 1/25
# 782/782 [==============================] - 8s 6ms/step - loss: 1.9743 - accuracy: 0.2993 - val_loss: 1.8876 - val_accuracy: 0.3303
# Epoch 2/25
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7241 - accuracy: 0.3964 - val_loss: 1.6767 - val_accuracy: 0.4009
# Epoch 3/25
# 782/782 [==============================] - 4s 5ms/step - loss: 1.5640 - accuracy: 0.4518 - val_loss: 1.5129 - val_accuracy: 0.4554
# Epoch 4/25
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4359 - accuracy: 0.4953 - val_loss: 1.4066 - val_accuracy: 0.4979
# Epoch 5/25
# 782/782 [==============================] - 4s 6ms/step - loss: 1.3440 - accuracy: 0.5287 - val_loss: 1.3532 - val_accuracy: 0.5123
# Epoch 6/25
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2801 - accuracy: 0.5506 - val_loss: 1.3897 - val_accuracy: 0.5069
# Epoch 7/25
# 782/782 [==============================] - 4s 5ms/step - loss: 1.2298 - accuracy: 0.5707 - val_loss: 1.2845 - val_accuracy: 0.5404
# Epoch 8/25
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1897 - accuracy: 0.5864 - val_loss: 1.2262 - val_accuracy: 0.5662
# Epoch 9/25
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1520 - accuracy: 0.6002 - val_loss: 1.1818 - val_accuracy: 0.5784
# Epoch 10/25
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1215 - accuracy: 0.6106 - val_loss: 1.2974 - val_accuracy: 0.5440
# Epoch 11/25
# 782/782 [==============================] - 4s 6ms/step - loss: 1.0898 - accuracy: 0.6239 - val_loss: 1.1861 - val_accuracy: 0.5789
# Epoch 12/25
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0573 - accuracy: 0.6349 - val_loss: 1.1600 - val_accuracy: 0.5804
# Epoch 13/25
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0303 - accuracy: 0.6439 - val_loss: 1.1438 - val_accuracy: 0.5940
# Epoch 14/25
# 782/782 [==============================] - 4s 5ms/step - loss: 1.0031 - accuracy: 0.6535 - val_loss: 1.1370 - val_accuracy: 0.5924
# Epoch 15/25
# 782/782 [==============================] - 4s 5ms/step - loss: 0.9769 - accuracy: 0.6638 - val_loss: 1.1296 - val_accuracy: 0.6109
# Epoch 16/25
# 782/782 [==============================] - 4s 5ms/step - loss: 0.9500 - accuracy: 0.6724 - val_loss: 1.0922 - val_accuracy: 0.6171
# Epoch 17/25
# 782/782 [==============================] - 6s 8ms/step - loss: 0.9241 - accuracy: 0.6832 - val_loss: 1.1945 - val_accuracy: 0.5865
# Epoch 18/25
# 782/782 [==============================] - 5s 6ms/step - loss: 0.8983 - accuracy: 0.6903 - val_loss: 1.1434 - val_accuracy: 0.5978
# Epoch 19/25
# 782/782 [==============================] - 4s 5ms/step - loss: 0.8757 - accuracy: 0.6991 - val_loss: 1.0781 - val_accuracy: 0.6248
# Epoch 20/25
# 782/782 [==============================] - 4s 5ms/step - loss: 0.8515 - accuracy: 0.7063 - val_loss: 1.0992 - val_accuracy: 0.6234
# Epoch 21/25
# 782/782 [==============================] - 4s 5ms/step - loss: 0.8265 - accuracy: 0.7161 - val_loss: 1.1499 - val_accuracy: 0.5987
# Epoch 22/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.8045 - accuracy: 0.7238 - val_loss: 1.2596 - val_accuracy: 0.5620
# Epoch 23/25
# 782/782 [==============================] - 4s 5ms/step - loss: 0.7810 - accuracy: 0.7324 - val_loss: 1.1930 - val_accuracy: 0.5910
# Epoch 24/25
# 782/782 [==============================] - 4s 5ms/step - loss: 0.7591 - accuracy: 0.7415 - val_loss: 1.0756 - val_accuracy: 0.6255
# Epoch 25/25
# 782/782 [==============================] - 4s 5ms/step - loss: 0.7357 - accuracy: 0.7517 - val_loss: 1.0904 - val_accuracy: 0.6314

# %%
# Mostramos la pérdida y el acierto por cada época

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Pérdida')
plt.xlabel('Época')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('% Acierto')
plt.xlabel('Época')
plt.show()

# %% [markdown]
# ## Ejercicio: Mejorando el acierto con más capas
#
# La red anterior aunque muy simple, alcanzó un acierto de sobre 60% en unas pocas épocas lo que está muy por encima de la red feed-forward del laboratorio pasado. Lo otro que es fácil notar, si graficaste la pérdida y el acierto, es que la red tiene un sobreajuste (overfitting) considerable,  por lo que sería bueno no solo agregar capas si no también agregar regularización.
#
# Ahora crearás una red convolucional de 3 capas convolucionales y dos capas densas para mejorar la predicción y además agregarás capas de dropout intermedias. Tu red debe tener esta arquitectura
#
# **Convolucional 32 (3x3) -->  Convolucional 32 (3x3) -->  Max Pooling (2x2) --> Convolucional 64 (3x3) --> Max Pooling (2x2) --> Densa 512 -->  Densa 10**
#
# Considera todas las activaciones como `relu`. Si hiciste todo bien, tu red debiera tener alrededor de **1,2M parámetros**. Nota que  es bastante menos que para la red anterior incluso cuando la anterior tenía menos capas (¿puedes explicar por qué?).
#
# Debes realizar lo siguiente:
# - Entrena primero con la arquitectura de arriba sin regularización. Hazlo solo por 30 épocas.
# - Imprime la pérdida y el acierto por cada época y nota que mejora el acierto, pero que hay  un alto sobreajuste.
# - Posteriormente agrega algunas capas de dropout, dos o tres con una tasa de dropout moderada (0.2 a 0.3), y entrena otra vez por 40 épocas
# - Imprime la pérdida y el acierto por cada época y asegúrate que mejora el acierto y baja el sobre ajuste. Haz los cambios que estimes convenientes para mejorar las métricas.
#
# En el último paso deberías llegar al menos a un 70% de acierto en el conjunto de prueba (si no lo alcanzas, intenta haciendo cambios como hemos aprendido en clases).  Opcionalmente muestra algunos ejemplos de las predicciones de tu red y guarda el modelo para usarlo posteriormente.

# %% [markdown]
# ### a) Crea la arquitectura
#
# Crea la arquitectura con 3 capas convolucionales y dos densas, imprime el resumen de la red y entrénala por 30 épocas.<br>
#  activaciones como relu. Si hiciste todo bien, tu red debiera tener alrededor de 1,2M parámetros.

# %% [markdown]
# Convolucional 32 (3x3) --> Convolucional 32 (3x3) --> Max Pooling (2x2) --> Convolucional 64 (3x3) --> Max Pooling (2x2) --> Densa 512 --> Densa 10

# %%
# Creamos una red neuronal convolucional simple

red_conv = keras.Sequential()
#Según la PPT
#Los hiperParámetros en la capa Conv2d quedan así:
#K = Numero de Kernels en la capa
#F = Extensión espacial del kernel (tamaño)
#S = el Stride = De cuantos pixeles avanzo en cada iteración de la aplicación de la convolución
#P = el Padding = La cantidad de pixeles a agregar en los bordes llenos con ceros. Para un Kernel de 3x3, la idea es un padding de 2x2, esto agrega 1 pixel arriba, 1 abajo, 1 a la izq y uno a la der
#Conv2D(K, F, strides=S, input_shape=(32,32,3), activation='relu')
#MaxPoll2D(Tamaño, S)
#Con esto se puede calcular el tamaño del mapa de activación resultante de la capa, así:
#Considerando que la entrada tiene tamaño W (si la imagen es de 5x5, entonces W = 5)
#Para el ejemplo de abajo, sería: W=32, K=64, F=3, S=1, P=1       -> Padding 1 porque al ser 2x2 agrega 1 pixel a cada lado, y la fórmula siguiente considera cada parámetro como 1 lado
#La fórmula es: ((W-F+2P)/S)+1
#Entonces: ((32-3+2*1)/1)+1 = 32    -> Manteniendo la relación de aspecto de la imagen de entrada con la de salida

#La fórmula para calcular los parámetros de la capa convolucional es:
# K x (tamaño del kernel) + K
# Si el kernel es de 3x3 y las imágenes tiene 3 canales de entrada (por ser RGB), entonces el kernel es 3x3x3
# La fórmula sería: 64 * (3 * 3 * 3) + 64 = 1792

red_conv.add(Conv2D(32, (3,3), strides=(1, 1), input_shape=(32,32,3), activation='relu')) #-> Primero se aplican las convoluciones, luego la función de activación
red_conv.add(Conv2D(32, (3,3), strides=(1, 1), input_shape=(32,32,3), activation='relu')) #-> Primero se aplican las convoluciones, luego
red_conv.add(MaxPool2D((2,2)))
red_conv.add(Conv2D(64, (3,3), strides=(1, 1), input_shape=(64,32,3), activation='relu')) #-> Primero se aplican las convoluciones, luego
red_conv.add(MaxPool2D((2,2)))
red_conv.add(Flatten())
red_conv.add(Dense(512, activation='relu'))
red_conv.add(Dense(10, activation='softmax'))

red_conv.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 30, 30, 32)        896
#
#  conv2d_16 (Conv2D)          (None, 28, 28, 32)        9248
#
#  max_pooling2d_7 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 12, 12, 64)        18496
#
#  max_pooling2d_8 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 2304)              0
#
#  dense_14 (Dense)            (None, 512)               1180160
#
#  dense_15 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1213930 (4.63 MB)
# Trainable params: 1213930 (4.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
red_conv.compile(
    loss='categorical_crossentropy',
    optimizer='sgd',  #-> adam es mejor función de optimizador que sgd
    metrics=['accuracy']
)


hist = red_conv.fit(
    X_train,Y_train,
    batch_size=64,
    epochs=30,
    validation_data=(X_test,Y_test)
)
# Out:
# Epoch 1/30
# 782/782 [==============================] - 8s 7ms/step - loss: 2.1054 - accuracy: 0.2307 - val_loss: 1.9632 - val_accuracy: 0.2856
# Epoch 2/30
# 782/782 [==============================] - 4s 6ms/step - loss: 1.7897 - accuracy: 0.3642 - val_loss: 1.8423 - val_accuracy: 0.3550
# Epoch 3/30
# 782/782 [==============================] - 5s 7ms/step - loss: 1.5608 - accuracy: 0.4445 - val_loss: 1.5571 - val_accuracy: 0.4463
# Epoch 4/30
# 782/782 [==============================] - 5s 6ms/step - loss: 1.4301 - accuracy: 0.4946 - val_loss: 1.4179 - val_accuracy: 0.4953
# Epoch 5/30
# 782/782 [==============================] - 5s 6ms/step - loss: 1.3470 - accuracy: 0.5248 - val_loss: 1.4613 - val_accuracy: 0.4865
# Epoch 6/30
# 782/782 [==============================] - 6s 8ms/step - loss: 1.2819 - accuracy: 0.5477 - val_loss: 1.5344 - val_accuracy: 0.4644
# Epoch 7/30
# 782/782 [==============================] - 5s 6ms/step - loss: 1.2216 - accuracy: 0.5702 - val_loss: 1.3147 - val_accuracy: 0.5320
# Epoch 8/30
# 782/782 [==============================] - 5s 6ms/step - loss: 1.1683 - accuracy: 0.5898 - val_loss: 1.2622 - val_accuracy: 0.5552
# Epoch 9/30
# 782/782 [==============================] - 4s 6ms/step - loss: 1.1125 - accuracy: 0.6109 - val_loss: 1.2190 - val_accuracy: 0.5809
# Epoch 10/30
# 782/782 [==============================] - 5s 6ms/step - loss: 1.0637 - accuracy: 0.6291 - val_loss: 1.2833 - val_accuracy: 0.5530
# Epoch 11/30
# 782/782 [==============================] - 5s 7ms/step - loss: 1.0140 - accuracy: 0.6455 - val_loss: 1.1862 - val_accuracy: 0.5856
# Epoch 12/30
# 782/782 [==============================] - 5s 6ms/step - loss: 0.9607 - accuracy: 0.6683 - val_loss: 1.2336 - val_accuracy: 0.5739
# Epoch 13/30
# 782/782 [==============================] - 5s 6ms/step - loss: 0.9111 - accuracy: 0.6845 - val_loss: 1.2147 - val_accuracy: 0.5869
# Epoch 14/30
# 782/782 [==============================] - 5s 6ms/step - loss: 0.8648 - accuracy: 0.6987 - val_loss: 1.2624 - val_accuracy: 0.5657
# Epoch 15/30
# 782/782 [==============================] - 4s 6ms/step - loss: 0.8165 - accuracy: 0.7165 - val_loss: 1.1299 - val_accuracy: 0.6202
# Epoch 16/30
# 782/782 [==============================] - 5s 6ms/step - loss: 0.7677 - accuracy: 0.7330 - val_loss: 1.1869 - val_accuracy: 0.6090
# Epoch 17/30
# 782/782 [==============================] - 5s 6ms/step - loss: 0.7170 - accuracy: 0.7516 - val_loss: 1.2081 - val_accuracy: 0.6051
# Epoch 18/30
# 782/782 [==============================] - 4s 6ms/step - loss: 0.6683 - accuracy: 0.7692 - val_loss: 1.4599 - val_accuracy: 0.5666
# Epoch 19/30
# 782/782 [==============================] - 5s 7ms/step - loss: 0.6192 - accuracy: 0.7856 - val_loss: 1.2666 - val_accuracy: 0.6126
# Epoch 20/30
# 782/782 [==============================] - 4s 6ms/step - loss: 0.5750 - accuracy: 0.7997 - val_loss: 1.5870 - val_accuracy: 0.5504
# Epoch 21/30
# 782/782 [==============================] - 5s 6ms/step - loss: 0.5250 - accuracy: 0.8178 - val_loss: 1.5807 - val_accuracy: 0.5667
# Epoch 22/30
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4791 - accuracy: 0.8336 - val_loss: 1.7837 - val_accuracy: 0.5477
# Epoch 23/30
# 782/782 [==============================] - 5s 6ms/step - loss: 0.4342 - accuracy: 0.8493 - val_loss: 1.3866 - val_accuracy: 0.6216
# Epoch 24/30
# 782/782 [==============================] - 5s 6ms/step - loss: 0.3894 - accuracy: 0.8645 - val_loss: 1.6560 - val_accuracy: 0.5892
# Epoch 25/30
# 782/782 [==============================] - 5s 6ms/step - loss: 0.3447 - accuracy: 0.8809 - val_loss: 1.5224 - val_accuracy: 0.6211
# Epoch 26/30
# 782/782 [==============================] - 4s 6ms/step - loss: 0.3050 - accuracy: 0.8944 - val_loss: 1.6111 - val_accuracy: 0.6135
# Epoch 27/30
# 782/782 [==============================] - 5s 6ms/step - loss: 0.2624 - accuracy: 0.9096 - val_loss: 2.1248 - val_accuracy: 0.5641
# Epoch 28/30
# 782/782 [==============================] - 4s 5ms/step - loss: 0.2321 - accuracy: 0.9219 - val_loss: 2.1777 - val_accuracy: 0.5762
# Epoch 29/30
# 782/782 [==============================] - 4s 6ms/step - loss: 0.2009 - accuracy: 0.9322 - val_loss: 1.7567 - val_accuracy: 0.6239
# Epoch 30/30
# 782/782 [==============================] - 5s 6ms/step - loss: 0.1607 - accuracy: 0.9471 - val_loss: 2.0017 - val_accuracy: 0.6145

# %%
# Acá tu código


# Acá termina tu código

# %%
np.random.seed(30)
tf.random.set_seed(30)

# Acá tu código para compilar y entrenar la red

np.random.seed(30)
tf.random.set_seed(30)

# Acá termina tu código.

# %% [markdown]
# ### b) Imprime los resultados
#
# Muestra un gráfico con la pérdida y el acierto por época de entrenamiento. El acierto debiera mejorar tanto en el conjunto de entrenamiento como en el de prueba, pero también debiera notarse un sobreajuste considerable.

# %%
# Acá tu código para mostrar pérdida y acierto


# Acá termina tu código

# %%
# Mostramos la pérdida y el acierto por cada época

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Pérdida')
plt.xlabel('Época')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('% Acierto')
plt.xlabel('Época')
plt.show()

# %% [markdown]
# ### c) Agrega dropoup
#
# Agrega un par (al menos dos) capas de dropout con probabilidad moderada (0.2 a 0.3), reentrena por 30-40 épocas.

# %%
# Acá tu código para la nueva red con dropout





# Acá termina tu código

# %%
np.random.seed(30)
tf.random.set_seed(30)

# Acá tu código para compilar y entrenar la red



# Acá termina tu codigo

# %% [markdown]
# ### d) Analiza los resultados y repite si fuera necesario
#
# Imprime las curvas de aprendizaje y asegúrate de que no hay un sobre ajuste considerable y que el acierto en el conjunto de prueba es al menos 70%. Si es necesario, repite la parte (e)  haciendo los cambios que estimes conveniente (como agregar otra capa de dropout o  aumentar la probabilidad de dropout si es que aun hay mucho sobreajuste).

# %%
# Acá tu código para mostrar pérdida y acierto



# Acá termina tu código

# %% [markdown]
# ### e) Opcional: ejemplos de predicciones
#
# Muestra ejemplos al azar de las predicciones de tu modelo con los ejemplos de prueba.

# %%
# Acá tu código para mostrar algunas predicciones



# Acá termina tu código
